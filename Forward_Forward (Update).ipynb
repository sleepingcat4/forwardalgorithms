# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import random
from tensorflow.compiler.tf2xla.python import xla

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

print("4 Random Training samples and labels")
idx1, idx2, idx3, idx4 = random.sample(range(0, x_train.shape[0]), 4)

img1 = (x_train[idx1], y_train[idx1])
img2 = (x_train[idx2], y_train[idx2])
img3 = (x_train[idx3], y_train[idx3])
img4 = (x_train[idx4], y_train[idx4])

imgs = [img1, img2, img3, img4]

plt.figure(figsize=(10, 10))

for idx, item in enumerate(imgs):
    image, label = item[0], item[1]
    plt.subplot(2, 2, idx + 1)
    plt.imshow(image, cmap="gray")
    plt.title(f"Label : {label}")
plt.show()
# Out:
# 4 Random Training samples and labels

# %%
class FFDense(keras.layers.Layer):
    """
    A custom ForwardForward-enabled Dense layer. It has an implementation of the
    Forward-Forward network internally for use.
    This layer must be used in conjunction with the `FFNetwork` model.
    """

    def __init__(
        self,
        units,
        optimizer,
        loss_metric,
        num_epochs=50,
        use_bias=True,
        kernel_initializer="glorot_uniform",
        bias_initializer="zeros",
        kernel_regularizer=None,
        bias_regularizer=None,
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.dense = keras.layers.Dense(
            units=units,
            use_bias=use_bias,
            kernel_initializer=kernel_initializer,
            bias_initializer=bias_initializer,
            kernel_regularizer=kernel_regularizer,
            bias_regularizer=bias_regularizer,
        )
        self.relu = keras.layers.ReLU()
        self.optimizer = optimizer
        self.loss_metric = loss_metric
        self.threshold = 1.5
        self.num_epochs = num_epochs

    # We perform a normalization step before we run the input through the Dense
    # layer.

    def call(self, x):
        x_norm = tf.norm(x, ord=2, axis=1, keepdims=True)
        x_norm = x_norm + 1e-4
        x_dir = x / x_norm
        res = self.dense(x_dir)
        return self.relu(res)

    # The Forward-Forward algorithm is below. We first perform the Dense-layer
    # operation and then get a Mean Square value for all positive and negative
    # samples respectively.
    # The custom loss function finds the distance between the Mean-squared
    # result and the threshold value we set (a hyperparameter) that will define
    # whether the prediction is positive or negative in nature. Once the loss is
    # calculated, we get a mean across the entire batch combined and perform a
    # gradient calculation and optimization step. This does not technically
    # qualify as backpropagation since there is no gradient being
    # sent to any previous layer and is completely local in nature.

    def forward_forward(self, x_pos, x_neg):
        for i in range(self.num_epochs):
            with tf.GradientTape() as tape:
                g_pos = tf.math.reduce_mean(tf.math.pow(self.call(x_pos), 2), 1)
                g_neg = tf.math.reduce_mean(tf.math.pow(self.call(x_neg), 2), 1)

                loss = tf.math.log(
                    1
                    + tf.math.exp(
                        tf.concat([-g_pos + self.threshold, g_neg - self.threshold], 0)
                    )
                )
                mean_loss = tf.cast(tf.math.reduce_mean(loss), tf.float32)
                self.loss_metric.update_state([mean_loss])
            gradients = tape.gradient(mean_loss, self.dense.trainable_weights)
            self.optimizer.apply_gradients(zip(gradients, self.dense.trainable_weights))
        return (
            tf.stop_gradient(self.call(x_pos)),
            tf.stop_gradient(self.call(x_neg)),
            self.loss_metric.result(),
        )

# %%
x_train = x_train.astype(float) / 255
x_test = x_test.astype(float) / 255
y_train = y_train.astype(int)
y_test = y_test.astype(int)

train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))

train_dataset = train_dataset.batch(60000)
test_dataset = test_dataset.batch(10000)

# %%
model = FFNetwork(dims=[784, 500, 500])

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.03),
    loss="mse",
    jit_compile=True,
    metrics=[keras.metrics.Mean()],
)

epochs = 250
history = model.fit(train_dataset, epochs=epochs)
# Out:
# Epoch 1/250
# Training layer 1 now :
# Training layer 2 now :
# Training layer 1 now :
# Training layer 2 now :
# 1/1 [==============================] - 94s 94s/step - FinalLoss: 0.7271
# Epoch 2/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.7086
# Epoch 3/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.6972
# Epoch 4/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.6755
# Epoch 5/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.6525
# Epoch 6/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.6311
# Epoch 7/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.6121
# Epoch 8/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.5955
# Epoch 9/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.5806
# Epoch 10/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.5674
# Epoch 11/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.5556
# Epoch 12/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.5449
# Epoch 13/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.5350
# Epoch 14/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.5260
# Epoch 15/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.5178
# Epoch 16/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.5102
# Epoch 17/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.5032
# Epoch 18/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4967
# Epoch 19/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4907
# Epoch 20/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4851
# Epoch 21/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4799
# Epoch 22/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4750
# Epoch 23/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4704
# Epoch 24/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4660
# Epoch 25/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4619
# Epoch 26/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4581
# Epoch 27/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4543
# Epoch 28/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4508
# Epoch 29/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4475
# Epoch 30/250
# 1/1 [==============================] - 7s 7s/step - FinalLoss: 0.4443
# Epoch 31/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4412
# Epoch 32/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4383
# Epoch 33/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4356
# Epoch 34/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4330
# Epoch 35/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4305
# Epoch 36/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4281
# Epoch 37/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4258
# Epoch 38/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4237
# Epoch 39/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4215
# Epoch 40/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4194
# Epoch 41/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4174
# Epoch 42/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4155
# Epoch 43/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4136
# Epoch 44/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4118
# Epoch 45/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4100
# Epoch 46/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4083
# Epoch 47/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4067
# Epoch 48/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4051
# Epoch 49/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4036
# Epoch 50/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4020
# Epoch 51/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.4005
# Epoch 52/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3991
# Epoch 53/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3977
# Epoch 54/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3963
# Epoch 55/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3950
# Epoch 56/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3937
# Epoch 57/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3924
# Epoch 58/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3912
# Epoch 59/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3900
# Epoch 60/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3889
# Epoch 61/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3877
# Epoch 62/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3866
# Epoch 63/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3855
# Epoch 64/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3844
# Epoch 65/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3834
# Epoch 66/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3824
# Epoch 67/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3813
# Epoch 68/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3803
# Epoch 69/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3794
# Epoch 70/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3784
# Epoch 71/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3775
# Epoch 72/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3765
# Epoch 73/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3756
# Epoch 74/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3747
# Epoch 75/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3739
# Epoch 76/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3730
# Epoch 77/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3722
# Epoch 78/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3713
# Epoch 79/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3705
# Epoch 80/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3698
# Epoch 81/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3689
# Epoch 82/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3681
# Epoch 83/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3674
# Epoch 84/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3667
# Epoch 85/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3659
# Epoch 86/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3652
# Epoch 87/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3645
# Epoch 88/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3638
# Epoch 89/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3631
# Epoch 90/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3624
# Epoch 91/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3617
# Epoch 92/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3611
# Epoch 93/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3604
# Epoch 94/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3598
# Epoch 95/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3592
# Epoch 96/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3585
# Epoch 97/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3579
# Epoch 98/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3573
# Epoch 99/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3567
# Epoch 100/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3561
# Epoch 101/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3555
# Epoch 102/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3549
# Epoch 103/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3544
# Epoch 104/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3538
# Epoch 105/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3532
# Epoch 106/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3527
# Epoch 107/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3521
# Epoch 108/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3516
# Epoch 109/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3511
# Epoch 110/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3506
# Epoch 111/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3500
# Epoch 112/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3495
# Epoch 113/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3490
# Epoch 114/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3485
# Epoch 115/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3480
# Epoch 116/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3475
# Epoch 117/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3471
# Epoch 118/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3466
# Epoch 119/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.3462
# Epoch 120/250
# 1/1 [==============================] - 6s 6s/step - FinalLoss: 0.